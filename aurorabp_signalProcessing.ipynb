# %% [markdown]
# ### *Bibliotecas e módulos*

# %%
pip install pandas

pip install sweetviz

pip install numpy

pip install scikit-learn

# %%
import pandas as pd

# %% [markdown]
# ## ```Leitura do dataset: Initial Calibration.tsv```

# %%
initCalib_df = pd.read_csv('./a000.initial.Calibration_start_1.tsv', sep="\t")

initCalib_df
# Out:
#                  t     ekg   optical  pressure  accel_x   accel_y  accel_z
# 0     1.136900e-13  6.5104 -581380.0    2901.6 -0.88962  0.047824  0.42700
# 1     2.000000e-03  6.5078 -581380.0    2901.5 -0.88953  0.048214  0.42641
# 2     4.000000e-03  6.5093 -581380.0    2901.4 -0.88943  0.048605  0.42583
# 3     6.000000e-03  6.5157 -581380.0    2901.2 -0.88933  0.048995  0.42524
# 4     8.000000e-03  6.5249 -581390.0    2901.1 -0.88923  0.049386  0.42466
# ...            ...     ...       ...       ...      ...       ...      ...
# 9270  1.854000e+01  4.0478 -580930.0    2855.7 -0.88523  0.051728  0.42212
# 9271  1.854200e+01  4.0500 -580930.0    2855.5 -0.88455  0.051435  0.42241
# 9272  1.854400e+01  4.0529 -580940.0    2855.4 -0.88387  0.051142  0.42271
# 9273  1.854600e+01  4.0546 -580940.0    2855.3 -0.88318  0.050850  0.42300
# 9274  1.854800e+01  4.0498 -580940.0    2855.1 -0.88250  0.050557  0.42329
#
# [9275 rows x 7 columns]

# %% [markdown]
# #### _Descrição das features:_

# %%
initCalib_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9275 entries, 0 to 9274
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   t         9275 non-null   float64
#  1   ekg       9275 non-null   float64
#  2   optical   9275 non-null   float64
#  3   pressure  9275 non-null   float64
#  4   accel_x   9275 non-null   float64
#  5   accel_y   9275 non-null   float64
#  6   accel_z   9275 non-null   float64
# dtypes: float64(7)
# memory usage: 507.4 KB

# %% [markdown]
# *t* $\rightarrow$ Tonometria: Exame que mede a pressão interna no olho. Os pesquisadores observaram que tonometria teve o maior sinal em performance para fins de predição da pressão sanguínea, produziu ondas mais ricas em features comparados com PPG e ECG como complemento. Porém, a tonometria é menos confortável.
#
# *ekg* $\rightarrow$ Ecocardiograma: pode estimar a presão sistólica arterial pulmonar e a presão venosa central, avaliando o tamanho e a função das cavidades cardíacas direitas;
#
# *optical* $\rightarrow$ Óptico: Refere-se à intensidade dos sensores ópticos utilizados para medir o volume sanguíneo;
#
# *accel_x* $\rightarrow$
#
# *accel_y* $\rightarrow$
#
# *accel_z* $\rightarrow$

# %% [markdown]
# ### Estudo dos gráficos das features

# %%
initCalib_df.max()
# Out:
# t               18.548000
# ekg              6.947900
# optical    -580870.000000
# pressure      2968.000000
# accel_x         -0.879380
# accel_y          0.059048
# accel_z          0.432860
# dtype: float64

# %%
initCalib_df.min()
# Out:
# t           1.136900e-13
# ekg         3.023600e+00
# optical    -5.819200e+05
# pressure    2.822400e+03
# accel_x    -9.023100e-01
# accel_y     4.148000e-02
# accel_z     4.167500e-01
# dtype: float64

# %%
svac = sv.analyze(initCalib_df)
svac.show_html()
# Out:
#                                              |      | [  0%]   00:00 -> (? left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# # **Dataset: features.tsv**

# %%
features_df = pd.read_csv('./features.tsv', sep='\t')

# %%
features_df
# Out:
#       pid       phase                 measurement            date_time    sbp  \
# 0    o000  ambulatory              measurement 23  2018-01-01 12:17:45    NaN
# 1    o000  ambulatory              measurement 25  2018-01-01 12:47:27  141.0
# 2    o000  ambulatory              measurement 27  2018-01-01 13:17:30  139.0
# 3    o000  ambulatory              measurement 28  2018-01-01 13:46:55    NaN
# 4    o000  ambulatory              measurement 30  2018-01-01 14:17:10    NaN
# ..    ...         ...                         ...                  ...    ...
# 380  a005      return  Temporal challenge start 1  2018-01-02 14:38:34  115.0
# 381  a005      return  Temporal challenge start 2  2018-01-02 14:40:13  109.0
# 382  a005      return  Temporal challenge start 3  2018-01-02 14:41:54  121.5
# 383  a005   synthetic  Calibration average values                  NaN  110.0
# 384  a005   synthetic  Calibration closest values                  NaN  110.0
#
# ...

# %%
features_df.fillna(0)
# Out:
#       pid       phase                 measurement            date_time    sbp  \
# 0    o000  ambulatory              measurement 23  2018-01-01 12:17:45    0.0
# 1    o000  ambulatory              measurement 25  2018-01-01 12:47:27  141.0
# 2    o000  ambulatory              measurement 27  2018-01-01 13:17:30  139.0
# 3    o000  ambulatory              measurement 28  2018-01-01 13:46:55    0.0
# 4    o000  ambulatory              measurement 30  2018-01-01 14:17:10    0.0
# ..    ...         ...                         ...                  ...    ...
# 380  a005      return  Temporal challenge start 1  2018-01-02 14:38:34  115.0
# 381  a005      return  Temporal challenge start 2  2018-01-02 14:40:13  109.0
# 382  a005      return  Temporal challenge start 3  2018-01-02 14:41:54  121.5
# 383  a005   synthetic  Calibration average values                    0  110.0
# 384  a005   synthetic  Calibration closest values                    0  110.0
#
# ...

# %%
features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 385 entries, 0 to 384
# Data columns (total 53 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   pid                                        385 non-null    object
#  1   phase                                      385 non-null    object
#  2   measurement                                385 non-null    object
#  3   date_time                                  351 non-null    object
#  4   sbp                                        366 non-null    float64
#  5   dbp                                        365 non-null    float64
#  6   baseline_sbp                               385 non-null    float64
#  7   baseline_dbp                               385 non-null    float64
#  8   delta_sbp                                  366 non-null    float64
#  9   delta_dbp                                  365 non-null    float64
# ...

# %%
import sweetviz as sv

# %%
sva.show_html()
# Out:
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
